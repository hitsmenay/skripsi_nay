# %%
# Import module
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# Sort by Month (ISPA)

# %%
# Add csv file
df_ispa = pd.read_csv('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/data_kesehatan/ispa_month/data_ispa.csv')
df_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.2  300 non-null    int64
#  1   Unnamed: 0.1  300 non-null    int64
#  2   Unnamed: 0    300 non-null    int64
#  3   KABKOT        300 non-null    object
#  4   month         300 non-null    int64
#  5   year          300 non-null    int64
#  6   longitude     300 non-null    float64
#  7   latitude      300 non-null    float64
#  8   RH            300 non-null    float64
#  9   time          300 non-null    object
#  10  t2m           300 non-null    float64
#  11  tp            300 non-null    float64
#  12  ispa          300 non-null    int64
# dtypes: float64(5), int64(6), object(2)
# memory usage: 30.6+ KB

# %%
# Drop the columns
df_ispa = df_ispa.drop(['Unnamed: 0'], axis=1)

# %%
df_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.2  300 non-null    int64
#  1   Unnamed: 0.1  300 non-null    int64
#  2   KABKOT        300 non-null    object
#  3   month         300 non-null    int64
#  4   year          300 non-null    int64
#  5   longitude     300 non-null    float64
#  6   latitude      300 non-null    float64
#  7   RH            300 non-null    float64
#  8   time          300 non-null    object
#  9   t2m           300 non-null    float64
#  10  tp            300 non-null    float64
#  11  ispa          300 non-null    int64
# dtypes: float64(5), int64(5), object(2)
# memory usage: 28.3+ KB

# %%
# Filter for years 2018-2022
data_ispa = df_ispa[(df_ispa['year'] >= 2018) & (df_ispa['year'] <= 2022)]

# Group sum_ispa by KABKOT, month, and time
ispa_sort = data_ispa.groupby(['KABKOT', 'month', 'time'])['ispa'].sum()

# %%
ispa_sort
# Out:
# KABKOT         month  time
# JAKARTA BARAT  1      2018-01-01    35036
#                       2019-01-01     1688
#                       2020-01-01    30245
#                       2021-01-01     8616
#                       2022-01-01    19330
#                                     ...
# JAKARTA UTARA  12     2018-12-01     9376
#                       2019-12-01    31251
#                       2020-12-01     6555
#                       2021-12-01    11270
#                       2022-12-01    25644
# Name: ispa, Length: 300, dtype: int64

# %% [markdown]
# Sort by Month (RH)

# %%
# Add file csv
df_ispa = pd.read_csv('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/data_kesehatan/ispa_month/data_ispa.csv')
df_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.2  300 non-null    int64
#  1   Unnamed: 0.1  300 non-null    int64
#  2   Unnamed: 0    300 non-null    int64
#  3   KABKOT        300 non-null    object
#  4   month         300 non-null    int64
#  5   year          300 non-null    int64
#  6   longitude     300 non-null    float64
#  7   latitude      300 non-null    float64
#  8   RH            300 non-null    float64
#  9   time          300 non-null    object
#  10  t2m           300 non-null    float64
#  11  tp            300 non-null    float64
#  12  ispa          300 non-null    int64
# dtypes: float64(5), int64(6), object(2)
# memory usage: 30.6+ KB

# %%
# Drop the columns
df_rh = df_ispa.drop(['Unnamed: 0', 'ispa', 'Unnamed: 0.2', 'Unnamed: 0.1', 'tp', 't2m'], axis=1)

# %%
df_rh
# Out:
#             KABKOT  month  year   longitude  latitude         RH        time
# 0    JAKARTA BARAT      1  2018  106.750000 -6.158333  81.914160  2018-01-01
# 1    JAKARTA BARAT      2  2018  106.750000 -6.158333  85.607633  2018-02-01
# 2    JAKARTA BARAT      3  2018  106.750000 -6.158333  83.613396  2018-03-01
# 3    JAKARTA BARAT      4  2018  106.750000 -6.158333  83.669416  2018-04-01
# 4    JAKARTA BARAT      5  2018  106.750000 -6.158333  80.346159  2018-05-01
# ..             ...    ...   ...         ...       ...        ...         ...
# 295  JAKARTA UTARA      8  2022  106.891667 -6.125000  79.779854  2022-08-01
# 296  JAKARTA UTARA      9  2022  106.891667 -6.125000  80.356575  2022-09-01
# 297  JAKARTA UTARA     10  2022  106.891667 -6.125000  82.717352  2022-10-01
# 298  JAKARTA UTARA     11  2022  106.891667 -6.125000  82.045862  2022-11-01
# 299  JAKARTA UTARA     12  2022  106.891667 -6.125000  83.006588  2022-12-01
#
# [300 rows x 7 columns]

# %%
# Filter for years 2018-2022
data_rh = df_rh[(df_rh['year'] >= 2018) & (df_rh['year'] <= 2022)]

# Group mean_RH by KABKOT, month, and time
rh_sort = data_rh.groupby(['KABKOT', 'month', 'time'])['RH'].mean()

# %%
rh_sort
# Out:
# KABKOT         month  time
# JAKARTA BARAT  1      2018-01-01    81.914160
#                       2019-01-01    83.683022
#                       2020-01-01    85.895006
#                       2021-01-01    85.869056
#                       2022-01-01    83.321066
#                                       ...
# JAKARTA UTARA  12     2018-12-01    80.907944
#                       2019-12-01    82.433364
#                       2020-12-01    83.099855
#                       2021-12-01    83.487948
#                       2022-12-01    83.006588
# Name: RH, Length: 300, dtype: float64

# %% [markdown]
# Merge ISPA and RH (sorted)

# %%
merge_ispa_rh = pd.merge(ispa_sort, rh_sort, on=['KABKOT','month','time'])

# %%
merge_ispa_rh
# Out:
#                                  ispa         RH
# KABKOT        month time
# JAKARTA BARAT 1     2018-01-01  35036  81.914160
#                     2019-01-01   1688  83.683022
#                     2020-01-01  30245  85.895006
#                     2021-01-01   8616  85.869056
#                     2022-01-01  19330  83.321066
# ...                               ...        ...
# JAKARTA UTARA 12    2018-12-01   9376  80.907944
#                     2019-12-01  31251  82.433364
#                     2020-12-01   6555  83.099855
#                     2021-12-01  11270  83.487948
#                     2022-12-01  25644  83.006588
#
# [300 rows x 2 columns]

# %%
overlay = merge_ispa_rh.groupby(['KABKOT', 'month']).agg({'ispa':'sum', 'RH':'mean'}).reset_index()
# reset_index() untuk memisahkan kolom KABKOT dan month

# rename columns
overlay = overlay.rename(columns={'ispa': 'sum_ispa', 'RH':'mean_rh'})
overlay
# Out:
#              KABKOT  month  sum_ispa    mean_rh
# 0     JAKARTA BARAT      1     94915  84.136462
# 1     JAKARTA BARAT      2     61569  85.301538
# 2     JAKARTA BARAT      3     56608  83.478376
# 3     JAKARTA BARAT      4     39893  83.119352
# 4     JAKARTA BARAT      5     31488  81.919704
# 5     JAKARTA BARAT      6     41114  80.470796
# 6     JAKARTA BARAT      7     36988  75.992514
# 7     JAKARTA BARAT      8     39798  74.747955
# 8     JAKARTA BARAT      9     48285  74.609813
# 9     JAKARTA BARAT     10     57399  76.345355
# 10    JAKARTA BARAT     11     63735  80.205501
# 11    JAKARTA BARAT     12     63056  82.572568
# 12    JAKARTA PUSAT      1     71781  84.241383
# 13    JAKARTA PUSAT      2     48269  85.504867
# 14    JAKARTA PUSAT      3     50869  83.588739
# 15    JAKARTA PUSAT      4     29801  83.170150
# 16    JAKARTA PUSAT      5     22572  81.883076
# 17    JAKARTA PUSAT      6     34889  80.506588
# 18    JAKARTA PUSAT      7     25633  76.042754
# 19    JAKARTA PUSAT      8     27711  74.767871
# 20    JAKARTA PUSAT      9     38480  74.473330
# 21    JAKARTA PUSAT     10     43293  76.653341
# 22    JAKARTA PUSAT     11     41650  80.647847
# 23    JAKARTA PUSAT     12     41666  82.701963
# 24  JAKARTA SELATAN      1    138697  84.540954
# 25  JAKARTA SELATAN      2    119833  85.823629
# 26  JAKARTA SELATAN      3    108369  83.791878
# 27  JAKARTA SELATAN      4     78491  83.488625
# 28  JAKARTA SELATAN      5     65539  82.110082
# 29  JAKARTA SELATAN      6     68322  80.681330
# 30  JAKARTA SELATAN      7     73884  75.708220
# 31  JAKARTA SELATAN      8     79005  74.537322
# 32  JAKARTA SELATAN      9     85890  74.330118
# 33  JAKARTA SELATAN     10     79083  76.752429
# 34  JAKARTA SELATAN     11    101603  80.811946
# 35  JAKARTA SELATAN     12     91879  82.988795
# 36    JAKARTA TIMUR      1    171693  84.530151
# 37    JAKARTA TIMUR      2    151977  85.872577
# 38    JAKARTA TIMUR      3    127076  83.907648
# 39    JAKARTA TIMUR      4     89279  83.456792
# 40    JAKARTA TIMUR      5    213084  82.055971
# 41    JAKARTA TIMUR      6     77162  80.765354
# 42    JAKARTA TIMUR      7     87583  76.262358
# 43    JAKARTA TIMUR      8    118355  75.008375
# 44    JAKARTA TIMUR      9    110412  74.657764
# 45    JAKARTA TIMUR     10    145659  77.243441
# 46    JAKARTA TIMUR     11    134105  81.230609
# 47    JAKARTA TIMUR     12    119524  83.051423
# 48    JAKARTA UTARA      1     97312  84.112287
# 49    JAKARTA UTARA      2    100404  85.256014
# 50    JAKARTA UTARA      3     93590  83.463090
# 51    JAKARTA UTARA      4     66028  82.967041
# 52    JAKARTA UTARA      5     57358  81.850632
# 53    JAKARTA UTARA      6     58151  80.649720
# 54    JAKARTA UTARA      7     60637  76.841552
# 55    JAKARTA UTARA      8     69955  75.635157
# 56    JAKARTA UTARA      9     77409  75.325903
# 57    JAKARTA UTARA     10     82107  77.138230
# 58    JAKARTA UTARA     11     90796  80.655524
# 59    JAKARTA UTARA     12     84096  82.587139

# %% [markdown]
# Rename month for month_name

# %%
import calendar

# Format for monthly graph
overlay['month'] = pd.to_datetime(overlay['month'], format='%m').dt.month_name()

# Set the ['month_name'] as an index
overlay= overlay.set_index('month').reset_index()

# %%
# The result
overlay
# Out:
#         month           KABKOT  sum_ispa    mean_rh
# 0     January    JAKARTA BARAT     94915  84.136462
# 1    February    JAKARTA BARAT     61569  85.301538
# 2       March    JAKARTA BARAT     56608  83.478376
# 3       April    JAKARTA BARAT     39893  83.119352
# 4         May    JAKARTA BARAT     31488  81.919704
# 5        June    JAKARTA BARAT     41114  80.470796
# 6        July    JAKARTA BARAT     36988  75.992514
# 7      August    JAKARTA BARAT     39798  74.747955
# 8   September    JAKARTA BARAT     48285  74.609813
# 9     October    JAKARTA BARAT     57399  76.345355
# 10   November    JAKARTA BARAT     63735  80.205501
# 11   December    JAKARTA BARAT     63056  82.572568
# 12    January    JAKARTA PUSAT     71781  84.241383
# 13   February    JAKARTA PUSAT     48269  85.504867
# 14      March    JAKARTA PUSAT     50869  83.588739
# 15      April    JAKARTA PUSAT     29801  83.170150
# 16        May    JAKARTA PUSAT     22572  81.883076
# 17       June    JAKARTA PUSAT     34889  80.506588
# 18       July    JAKARTA PUSAT     25633  76.042754
# 19     August    JAKARTA PUSAT     27711  74.767871
# 20  September    JAKARTA PUSAT     38480  74.473330
# 21    October    JAKARTA PUSAT     43293  76.653341
# 22   November    JAKARTA PUSAT     41650  80.647847
# 23   December    JAKARTA PUSAT     41666  82.701963
# 24    January  JAKARTA SELATAN    138697  84.540954
# 25   February  JAKARTA SELATAN    119833  85.823629
# 26      March  JAKARTA SELATAN    108369  83.791878
# 27      April  JAKARTA SELATAN     78491  83.488625
# 28        May  JAKARTA SELATAN     65539  82.110082
# 29       June  JAKARTA SELATAN     68322  80.681330
# 30       July  JAKARTA SELATAN     73884  75.708220
# 31     August  JAKARTA SELATAN     79005  74.537322
# 32  September  JAKARTA SELATAN     85890  74.330118
# 33    October  JAKARTA SELATAN     79083  76.752429
# 34   November  JAKARTA SELATAN    101603  80.811946
# 35   December  JAKARTA SELATAN     91879  82.988795
# 36    January    JAKARTA TIMUR    171693  84.530151
# 37   February    JAKARTA TIMUR    151977  85.872577
# 38      March    JAKARTA TIMUR    127076  83.907648
# 39      April    JAKARTA TIMUR     89279  83.456792
# 40        May    JAKARTA TIMUR    213084  82.055971
# 41       June    JAKARTA TIMUR     77162  80.765354
# 42       July    JAKARTA TIMUR     87583  76.262358
# 43     August    JAKARTA TIMUR    118355  75.008375
# 44  September    JAKARTA TIMUR    110412  74.657764
# 45    October    JAKARTA TIMUR    145659  77.243441
# 46   November    JAKARTA TIMUR    134105  81.230609
# 47   December    JAKARTA TIMUR    119524  83.051423
# 48    January    JAKARTA UTARA     97312  84.112287
# 49   February    JAKARTA UTARA    100404  85.256014
# 50      March    JAKARTA UTARA     93590  83.463090
# 51      April    JAKARTA UTARA     66028  82.967041
# 52        May    JAKARTA UTARA     57358  81.850632
# 53       June    JAKARTA UTARA     58151  80.649720
# 54       July    JAKARTA UTARA     60637  76.841552
# 55     August    JAKARTA UTARA     69955  75.635157
# 56  September    JAKARTA UTARA     77409  75.325903
# 57    October    JAKARTA UTARA     82107  77.138230
# 58   November    JAKARTA UTARA     90796  80.655524
# 59   December    JAKARTA UTARA     84096  82.587139

# %% [markdown]
# Plot ISPA x RH

# %%
indicators = ['sum_ispa', 'mean_rh']

# Group data by KABKOT
grouped_data = overlay.groupby('KABKOT')

# Plot time series for 'tb' and 'pm2p5' for each KABKOT
fig, axs = plt.subplots(len(grouped_data), 1, figsize=(25, len(grouped_data)*5), sharex=False)


for (name, group), ax in zip(grouped_data, axs):
    x = group['month']
    y1 = group['sum_ispa']
    y2 = group['mean_rh']

    ax.plot(x, y1, label='Kejadian ISPA', marker='o', linewidth=3.5, color='darkcyan')
    ax.set_ylabel(f'{name} - Jumlah Kejadian ISPA (jiwa)', color='darkcyan', weight='bold')
    ax.tick_params(axis='y', labelcolor='darkcyan')

    ax2 = ax.twinx()
    ax2.plot(x, y2, label='Relative Humidity', marker='o',linewidth=3.5, color='brown')
    ax2.set_ylabel(f'{name} - Rata-Rata Kelembapan (%)', color='brown', weight='bold')
    ax2.tick_params(axis='y', labelcolor='brown')

    ax.legend(loc= 'upper left', fontsize=16)
    ax2.legend(loc= 'upper right', fontsize=16)

# Add common x-axis label
axs[-1].set_xlabel('Month', fontsize= 14)
axs[-1].set_title('JAKARTA UTARA', weight='bold', fontsize= 14)
axs[-2].set_title('JAKARTA TIMUR', weight='bold', fontsize= 14)
axs[-3].set_title('JAKARTA SELATAN', weight='bold', fontsize= 14)
axs[-4].set_title('JAKARTA PUSAT', weight='bold', fontsize= 14)
axs[-5].set_title('JAKARTA BARAT', weight='bold', fontsize= 14)

plt.tight_layout()
plt.show()
