# %%
# Import module
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# Sort by Month (ISPA)

# %%
# Add csv file
df_ispa = pd.read_csv('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/overlay_allvar/allvar_ispa_all.csv')
df_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  300 non-null    int64
#  1   Unnamed: 0    300 non-null    int64
#  2   KABKOT        300 non-null    object
#  3   month         300 non-null    int64
#  4   year          300 non-null    int64
#  5   longitude     300 non-null    float64
#  6   latitude      300 non-null    float64
#  7   pm2p5         300 non-null    float64
#  8   time          300 non-null    object
#  9   RH            300 non-null    float64
#  10  t2m           300 non-null    float64
#  11  tp            300 non-null    float64
#  12  ispa          300 non-null    int64
#  13  pm10          300 non-null    float64
#  14  so2           300 non-null    float64
#  15  ispa_balita   300 non-null    int64
#  16  ispa_5y       300 non-null    int64
# dtypes: float64(8), int64(7), object(2)
# memory usage: 40.0+ KB

# %%
# Drop the columns
df_ispa = df_ispa.drop(['Unnamed: 0'], axis=1)

# %%
df_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  300 non-null    int64
#  1   KABKOT        300 non-null    object
#  2   month         300 non-null    int64
#  3   year          300 non-null    int64
#  4   longitude     300 non-null    float64
#  5   latitude      300 non-null    float64
#  6   pm2p5         300 non-null    float64
#  7   time          300 non-null    object
#  8   RH            300 non-null    float64
#  9   t2m           300 non-null    float64
#  10  tp            300 non-null    float64
#  11  ispa          300 non-null    int64
#  12  pm10          300 non-null    float64
#  13  so2           300 non-null    float64
#  14  ispa_balita   300 non-null    int64
#  15  ispa_5y       300 non-null    int64
# dtypes: float64(8), int64(6), object(2)
# memory usage: 37.6+ KB

# %%
# Filter for years 2018-2022
data_ispa = df_ispa[(df_ispa['year'] >= 2018) & (df_ispa['year'] <= 2022)]

# Group sum_ispa by KABKOT, month, and time
ispa_sort = data_ispa.groupby(['KABKOT', 'month', 'time'])['ispa_5y'].sum()

# %%
ispa_sort
# Out:
# KABKOT         month  time
# JAKARTA BARAT  1      2018-01-01    21514
#                       2019-01-01    21402
#                       2020-01-01    28072
#                       2021-01-01     6443
#                       2022-01-01    13408
#                                     ...
# JAKARTA UTARA  12     2018-12-01    18216
#                       2019-12-01    22118
#                       2020-12-01     3194
#                       2021-12-01     7909
#                       2022-12-01    15913
# Name: ispa_5y, Length: 300, dtype: int64

# %% [markdown]
# Sort by Month (RH)

# %%
# Add file csv
df_ispa = pd.read_csv('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/overlay_allvar/allvar_ispa_all.csv')
df_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  300 non-null    int64
#  1   Unnamed: 0    300 non-null    int64
#  2   KABKOT        300 non-null    object
#  3   month         300 non-null    int64
#  4   year          300 non-null    int64
#  5   longitude     300 non-null    float64
#  6   latitude      300 non-null    float64
#  7   pm2p5         300 non-null    float64
#  8   time          300 non-null    object
#  9   RH            300 non-null    float64
#  10  t2m           300 non-null    float64
#  11  tp            300 non-null    float64
#  12  ispa          300 non-null    int64
#  13  pm10          300 non-null    float64
#  14  so2           300 non-null    float64
#  15  ispa_balita   300 non-null    int64
#  16  ispa_5y       300 non-null    int64
# dtypes: float64(8), int64(7), object(2)
# memory usage: 40.0+ KB

# %%
# Drop the columns
df_rh = df_ispa.drop(['Unnamed: 0', 'ispa_5y', 'Unnamed: 0.1', 'tp', 't2m'], axis=1)

# %%
df_rh
# Out:
#             KABKOT  month  year   longitude  latitude      pm2p5        time  \
# 0    JAKARTA BARAT      1  2018  106.750000 -6.158333  32.990347  2018-01-01
# 1    JAKARTA BARAT      2  2018  106.750000 -6.158333  39.145521  2018-02-01
# 2    JAKARTA BARAT      3  2018  106.750000 -6.158333  44.443065  2018-03-01
# 3    JAKARTA BARAT      4  2018  106.750000 -6.158333  61.214024  2018-04-01
# 4    JAKARTA BARAT      5  2018  106.750000 -6.158333  68.229752  2018-05-01
# ..             ...    ...   ...         ...       ...        ...         ...
# 295  JAKARTA UTARA      8  2022  106.891667 -6.125000  60.172357  2022-08-01
# 296  JAKARTA UTARA      9  2022  106.891667 -6.125000  61.185956  2022-09-01
# 297  JAKARTA UTARA     10  2022  106.891667 -6.125000  49.726068  2022-10-01
# 298  JAKARTA UTARA     11  2022  106.891667 -6.125000  46.806576  2022-11-01
# 299  JAKARTA UTARA     12  2022  106.891667 -6.125000  39.195320  2022-12-01
#
#             RH   ispa       pm10       so2  ispa_balita
# 0    81.914160  35036  47.294950  3.282244        13522
# 1    85.607633  36413  55.981318  3.608457        12937
# 2    83.613396  40051  63.225958  4.557899        12937
# 3    83.669416  33071  86.887396  5.501254        10849
# 4    80.346159  32266  96.986573  6.098758         9575
# ..         ...    ...        ...       ...          ...
# 295  79.779854  23712  85.524501  5.413889         6287
# 296  80.356575  29908  87.035939  5.163605         7962
# 297  82.717352  31637  70.626910  4.771141         8871
# 298  82.045862  36767  66.740500  4.642301        10906
# 299  83.006588  25644  56.155258  3.910819         9731
#
# [300 rows x 12 columns]

# %%
# Filter for years 2018-2022
data_rh = df_rh[(df_rh['year'] >= 2018) & (df_rh['year'] <= 2022)]

# Group mean_RH by KABKOT, month, and time
rh_sort = data_rh.groupby(['KABKOT', 'month', 'time'])['RH'].mean()

# %%
rh_sort
# Out:
# KABKOT         month  time
# JAKARTA BARAT  1      2018-01-01    81.914160
#                       2019-01-01    83.683022
#                       2020-01-01    85.895006
#                       2021-01-01    85.869056
#                       2022-01-01    83.321066
#                                       ...
# JAKARTA UTARA  12     2018-12-01    80.907944
#                       2019-12-01    82.433364
#                       2020-12-01    83.099855
#                       2021-12-01    83.487948
#                       2022-12-01    83.006588
# Name: RH, Length: 300, dtype: float64

# %% [markdown]
# Merge ISPA and RH (sorted)

# %%
merge_ispa_rh = pd.merge(ispa_sort, rh_sort, on=['KABKOT','month','time'])

# %%
merge_ispa_rh
# Out:
#                                 ispa_5y         RH
# KABKOT        month time
# JAKARTA BARAT 1     2018-01-01    21514  81.914160
#                     2019-01-01    21402  83.683022
#                     2020-01-01    28072  85.895006
#                     2021-01-01     6443  85.869056
#                     2022-01-01    13408  83.321066
# ...                                 ...        ...
# JAKARTA UTARA 12    2018-12-01    18216  80.907944
#                     2019-12-01    22118  82.433364
#                     2020-12-01     3194  83.099855
#                     2021-12-01     7909  83.487948
#                     2022-12-01    15913  83.006588
#
# [300 rows x 2 columns]

# %%
overlay = merge_ispa_rh.groupby(['KABKOT', 'month']).agg({'ispa_5y':'sum', 'RH':'mean'}).reset_index()
# reset_index() untuk memisahkan kolom KABKOT dan month

# rename columns
overlay = overlay.rename(columns={'ispa_5y': 'sum_ispa', 'RH':'mean_rh'})
overlay
# Out:
#              KABKOT  month  sum_ispa    mean_rh
# 0     JAKARTA BARAT      1     90839  84.136462
# 1     JAKARTA BARAT      2    108249  85.301538
# 2     JAKARTA BARAT      3    100122  83.478376
# 3     JAKARTA BARAT      4     68004  83.119352
# 4     JAKARTA BARAT      5     59732  81.919704
# 5     JAKARTA BARAT      6     53995  80.470796
# 6     JAKARTA BARAT      7     66370  75.992514
# 7     JAKARTA BARAT      8     73540  74.747955
# 8     JAKARTA BARAT      9     70522  74.609813
# 9     JAKARTA BARAT     10     77470  76.345355
# 10    JAKARTA BARAT     11     76085  80.205501
# 11    JAKARTA BARAT     12     75517  82.572568
# 12    JAKARTA PUSAT      1     66432  84.241383
# 13    JAKARTA PUSAT      2     69706  85.504867
# 14    JAKARTA PUSAT      3     68600  83.588739
# 15    JAKARTA PUSAT      4     57681  83.170150
# 16    JAKARTA PUSAT      5     38394  81.883076
# 17    JAKARTA PUSAT      6     47189  80.506588
# 18    JAKARTA PUSAT      7     39879  76.042754
# 19    JAKARTA PUSAT      8     48124  74.767871
# 20    JAKARTA PUSAT      9     52110  74.473330
# 21    JAKARTA PUSAT     10     56184  76.653341
# 22    JAKARTA PUSAT     11     53971  80.647847
# 23    JAKARTA PUSAT     12     55645  82.701963
# 24  JAKARTA SELATAN      1    106278  84.540954
# 25  JAKARTA SELATAN      2    119348  85.823629
# 26  JAKARTA SELATAN      3    113516  83.791878
# 27  JAKARTA SELATAN      4     83689  83.488625
# 28  JAKARTA SELATAN      5     64125  82.110082
# 29  JAKARTA SELATAN      6     67356  80.681330
# 30  JAKARTA SELATAN      7     77288  75.708220
# 31  JAKARTA SELATAN      8     81335  74.537322
# 32  JAKARTA SELATAN      9     79815  74.330118
# 33  JAKARTA SELATAN     10     76941  76.752429
# 34  JAKARTA SELATAN     11     89080  80.811946
# 35  JAKARTA SELATAN     12     85025  82.988795
# 36    JAKARTA TIMUR      1    123265  84.530151
# 37    JAKARTA TIMUR      2    158365  85.872577
# 38    JAKARTA TIMUR      3    131222  83.907648
# 39    JAKARTA TIMUR      4     88598  83.456792
# 40    JAKARTA TIMUR      5    214623  82.055971
# 41    JAKARTA TIMUR      6     17584  80.765354
# 42    JAKARTA TIMUR      7     92707  76.262358
# 43    JAKARTA TIMUR      8    117612  75.008375
# 44    JAKARTA TIMUR      9    109955  74.657764
# 45    JAKARTA TIMUR     10    128686  77.243441
# 46    JAKARTA TIMUR     11    121594  81.230609
# 47    JAKARTA TIMUR     12    109806  83.051423
# 48    JAKARTA UTARA      1     72042  84.112287
# 49    JAKARTA UTARA      2     92214  85.256014
# 50    JAKARTA UTARA      3     85883  83.463090
# 51    JAKARTA UTARA      4     60416  82.967041
# 52    JAKARTA UTARA      5     48798  81.850632
# 53    JAKARTA UTARA      6     49345  80.649720
# 54    JAKARTA UTARA      7     56893  76.841552
# 55    JAKARTA UTARA      8     59786  75.635157
# 56    JAKARTA UTARA      9     66534  75.325903
# 57    JAKARTA UTARA     10     69232  77.138230
# 58    JAKARTA UTARA     11     74014  80.655524
# 59    JAKARTA UTARA     12     67350  82.587139

# %% [markdown]
# Rename month for month_name

# %%
import calendar

# Format for monthly graph
overlay['month'] = pd.to_datetime(overlay['month'], format='%m').dt.month_name()

# Set the ['month_name'] as an index
overlay= overlay.set_index('month').reset_index()

# %%
# The result
overlay
# Out:
#         month           KABKOT  sum_ispa    mean_rh
# 0     January    JAKARTA BARAT     90839  84.136462
# 1    February    JAKARTA BARAT    108249  85.301538
# 2       March    JAKARTA BARAT    100122  83.478376
# 3       April    JAKARTA BARAT     68004  83.119352
# 4         May    JAKARTA BARAT     59732  81.919704
# 5        June    JAKARTA BARAT     53995  80.470796
# 6        July    JAKARTA BARAT     66370  75.992514
# 7      August    JAKARTA BARAT     73540  74.747955
# 8   September    JAKARTA BARAT     70522  74.609813
# 9     October    JAKARTA BARAT     77470  76.345355
# 10   November    JAKARTA BARAT     76085  80.205501
# 11   December    JAKARTA BARAT     75517  82.572568
# 12    January    JAKARTA PUSAT     66432  84.241383
# 13   February    JAKARTA PUSAT     69706  85.504867
# 14      March    JAKARTA PUSAT     68600  83.588739
# 15      April    JAKARTA PUSAT     57681  83.170150
# 16        May    JAKARTA PUSAT     38394  81.883076
# 17       June    JAKARTA PUSAT     47189  80.506588
# 18       July    JAKARTA PUSAT     39879  76.042754
# 19     August    JAKARTA PUSAT     48124  74.767871
# 20  September    JAKARTA PUSAT     52110  74.473330
# 21    October    JAKARTA PUSAT     56184  76.653341
# 22   November    JAKARTA PUSAT     53971  80.647847
# 23   December    JAKARTA PUSAT     55645  82.701963
# 24    January  JAKARTA SELATAN    106278  84.540954
# 25   February  JAKARTA SELATAN    119348  85.823629
# 26      March  JAKARTA SELATAN    113516  83.791878
# 27      April  JAKARTA SELATAN     83689  83.488625
# 28        May  JAKARTA SELATAN     64125  82.110082
# 29       June  JAKARTA SELATAN     67356  80.681330
# 30       July  JAKARTA SELATAN     77288  75.708220
# 31     August  JAKARTA SELATAN     81335  74.537322
# 32  September  JAKARTA SELATAN     79815  74.330118
# 33    October  JAKARTA SELATAN     76941  76.752429
# 34   November  JAKARTA SELATAN     89080  80.811946
# 35   December  JAKARTA SELATAN     85025  82.988795
# 36    January    JAKARTA TIMUR    123265  84.530151
# 37   February    JAKARTA TIMUR    158365  85.872577
# 38      March    JAKARTA TIMUR    131222  83.907648
# 39      April    JAKARTA TIMUR     88598  83.456792
# 40        May    JAKARTA TIMUR    214623  82.055971
# 41       June    JAKARTA TIMUR     17584  80.765354
# 42       July    JAKARTA TIMUR     92707  76.262358
# 43     August    JAKARTA TIMUR    117612  75.008375
# 44  September    JAKARTA TIMUR    109955  74.657764
# 45    October    JAKARTA TIMUR    128686  77.243441
# 46   November    JAKARTA TIMUR    121594  81.230609
# 47   December    JAKARTA TIMUR    109806  83.051423
# 48    January    JAKARTA UTARA     72042  84.112287
# 49   February    JAKARTA UTARA     92214  85.256014
# 50      March    JAKARTA UTARA     85883  83.463090
# 51      April    JAKARTA UTARA     60416  82.967041
# 52        May    JAKARTA UTARA     48798  81.850632
# 53       June    JAKARTA UTARA     49345  80.649720
# 54       July    JAKARTA UTARA     56893  76.841552
# 55     August    JAKARTA UTARA     59786  75.635157
# 56  September    JAKARTA UTARA     66534  75.325903
# 57    October    JAKARTA UTARA     69232  77.138230
# 58   November    JAKARTA UTARA     74014  80.655524
# 59   December    JAKARTA UTARA     67350  82.587139

# %% [markdown]
# Plot ISPA x RH

# %%
indicators = ['sum_ispa', 'mean_rh']

# Group data by KABKOT
grouped_data = overlay.groupby('KABKOT')

# Plot time series for 'tb' and 'pm2p5' for each KABKOT
fig, axs = plt.subplots(len(grouped_data), 1, figsize=(25, len(grouped_data)*5), sharex=False)


for (name, group), ax in zip(grouped_data, axs):
    x = group['month']
    y1 = group['sum_ispa']
    y2 = group['mean_rh']

    ax.plot(x, y1, label='Kejadian ISPA', marker='o', linewidth=3.5, color='darkcyan')
    ax.set_ylabel(f'{name} - Jumlah Kejadian ISPA (jiwa)', color='darkcyan', weight='bold')
    ax.tick_params(axis='y', labelcolor='darkcyan')

    ax2 = ax.twinx()
    ax2.plot(x, y2, label='Relative Humidity', marker='o',linewidth=3.5, color='brown')
    ax2.set_ylabel(f'{name} - Rata-Rata Kelembapan (%)', color='brown', weight='bold')
    ax2.tick_params(axis='y', labelcolor='brown')

    ax.legend(loc= 'upper left', fontsize=16)
    ax2.legend(loc= 'upper right', fontsize=16)

# Add common x-axis label
axs[-1].set_xlabel('Month', fontsize= 14)
axs[-1].set_title('JAKARTA UTARA', weight='bold', fontsize= 14)
axs[-2].set_title('JAKARTA TIMUR', weight='bold', fontsize= 14)
axs[-3].set_title('JAKARTA SELATAN', weight='bold', fontsize= 14)
axs[-4].set_title('JAKARTA PUSAT', weight='bold', fontsize= 14)
axs[-5].set_title('JAKARTA BARAT', weight='bold', fontsize= 14)

plt.tight_layout()
plt.show()
