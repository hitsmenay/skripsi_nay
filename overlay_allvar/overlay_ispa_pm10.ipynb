# %%
# Import module
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# Sort by Month (ISPA)

# %%
# Add csv file
df_ispa = pd.read_csv('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/overlay_allvar/allvar_ispa_all.csv')
df_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  300 non-null    int64
#  1   Unnamed: 0    300 non-null    int64
#  2   KABKOT        300 non-null    object
#  3   month         300 non-null    int64
#  4   year          300 non-null    int64
#  5   longitude     300 non-null    float64
#  6   latitude      300 non-null    float64
#  7   pm2p5         300 non-null    float64
#  8   time          300 non-null    object
#  9   RH            300 non-null    float64
#  10  t2m           300 non-null    float64
#  11  tp            300 non-null    float64
#  12  ispa          300 non-null    int64
#  13  pm10          300 non-null    float64
#  14  so2           300 non-null    float64
#  15  ispa_balita   300 non-null    int64
#  16  ispa_5y       300 non-null    int64
# dtypes: float64(8), int64(7), object(2)
# memory usage: 40.0+ KB

# %%
# Drop the columns
df_ispa = df_ispa.drop(['Unnamed: 0', 'RH', 'so2', 'pm10', 'pm2p5', 'tp', 't2m'], axis=1)

# %%
df_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  300 non-null    int64
#  1   KABKOT        300 non-null    object
#  2   month         300 non-null    int64
#  3   year          300 non-null    int64
#  4   longitude     300 non-null    float64
#  5   latitude      300 non-null    float64
#  6   time          300 non-null    object
#  7   ispa          300 non-null    int64
#  8   ispa_balita   300 non-null    int64
#  9   ispa_5y       300 non-null    int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 23.6+ KB

# %%
# Filter for years 2018-2022
data_ispa = df_ispa[(df_ispa['year'] >= 2018) & (df_ispa['year'] <= 2022)]

# Group sum_ispa by KABKOT, month, and time
ispa_sort = data_ispa.groupby(['KABKOT', 'month', 'time'])['ispa_5y'].sum()
ispa_sort
# Out:
# KABKOT         month  time
# JAKARTA BARAT  1      2018-01-01    21514
#                       2019-01-01    21402
#                       2020-01-01    28072
#                       2021-01-01     6443
#                       2022-01-01    13408
#                                     ...
# JAKARTA UTARA  12     2018-12-01    18216
#                       2019-12-01    22118
#                       2020-12-01     3194
#                       2021-12-01     7909
#                       2022-12-01    15913
# Name: ispa_5y, Length: 300, dtype: int64

# %% [markdown]
# Sort by Month (PM10)

# %%
# Add csv file
df_pm10 = pd.read_csv('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/overlay_allvar/allvar_ispa_all.csv')
df_pm10
# Out:
#      Unnamed: 0.1  Unnamed: 0         KABKOT  month  year   longitude  \
# 0               0           0  JAKARTA BARAT      1  2018  106.750000
# 1               1           1  JAKARTA BARAT      2  2018  106.750000
# 2               2           2  JAKARTA BARAT      3  2018  106.750000
# 3               3           3  JAKARTA BARAT      4  2018  106.750000
# 4               4           4  JAKARTA BARAT      5  2018  106.750000
# ..            ...         ...            ...    ...   ...         ...
# 295           295         295  JAKARTA UTARA      8  2022  106.891667
# 296           296         296  JAKARTA UTARA      9  2022  106.891667
# 297           297         297  JAKARTA UTARA     10  2022  106.891667
# 298           298         298  JAKARTA UTARA     11  2022  106.891667
# 299           299         299  JAKARTA UTARA     12  2022  106.891667
#
#      latitude      pm2p5        time         RH        t2m        tp   ispa  \
# 0   -6.158333  32.990347  2018-01-01  81.914160  27.059570  7.256567  35036
# 1   -6.158333  39.145521  2018-02-01  85.607633  26.742241  9.965402  36413
# 2   -6.158333  44.443065  2018-03-01  83.613396  27.245901  7.343809  40051
# 3   -6.158333  61.214024  2018-04-01  83.669416  27.659839  6.208611  33071
# 4   -6.158333  68.229752  2018-05-01  80.346159  28.083251  2.895800  32266
# ..        ...        ...         ...        ...        ...       ...    ...
# 295 -6.125000  60.172357  2022-08-01  79.779854  27.524175  2.435247  23712
# 296 -6.125000  61.185956  2022-09-01  80.356575  27.479439  4.522162  29908
# 297 -6.125000  49.726068  2022-10-01  82.717352  27.231961  8.589306  31637
# 298 -6.125000  46.806576  2022-11-01  82.045862  27.315895  5.543476  36767
# 299 -6.125000  39.195320  2022-12-01  83.006588  27.046689  7.970700  25644
#
#           pm10       so2  ispa_balita  ispa_5y
# 0    47.294950  3.282244        13522    21514
# 1    55.981318  3.608457        12937    23476
# 2    63.225958  4.557899        12937    27114
# 3    86.887396  5.501254        10849    22222
# 4    96.986573  6.098758         9575    22691
# ..         ...       ...          ...      ...
# 295  85.524501  5.413889         6287    17425
# 296  87.035939  5.163605         7962    21946
# 297  70.626910  4.771141         8871    22766
# 298  66.740500  4.642301        10906    25861
# 299  56.155258  3.910819         9731    15913
#
# [300 rows x 17 columns]

# %%
# Filter for years 2018-2022
data_pm10 = df_pm10[(df_pm10['year'] >= 2018) & (df_pm10['year'] <= 2022)]

# Group mean_RH by KABKOT, month, and time
pm10_sort = data_pm10.groupby(['KABKOT', 'month', 'time'])['pm10'].mean()
pm10_sort
# Out:
# KABKOT         month  time
# JAKARTA BARAT  1      2018-01-01    47.294950
#                       2019-01-01    56.890549
#                       2020-01-01    56.164344
#                       2021-01-01    55.754458
#                       2022-01-01    57.999436
#                                       ...
# JAKARTA UTARA  12     2018-12-01    59.224384
#                       2019-12-01    68.288062
#                       2020-12-01    44.226031
#                       2021-12-01    60.627811
#                       2022-12-01    56.155258
# Name: pm10, Length: 300, dtype: float64

# %% [markdown]
# Merge ISPA and pm2p5 (sorted)

# %%
merge_ispa_pm10 = pd.merge(ispa_sort, pm10_sort, on=['KABKOT','month','time'])
merge_ispa_pm10
# Out:
#                                 ispa_5y       pm10
# KABKOT        month time
# JAKARTA BARAT 1     2018-01-01    21514  47.294950
#                     2019-01-01    21402  56.890549
#                     2020-01-01    28072  56.164344
#                     2021-01-01     6443  55.754458
#                     2022-01-01    13408  57.999436
# ...                                 ...        ...
# JAKARTA UTARA 12    2018-12-01    18216  59.224384
#                     2019-12-01    22118  68.288062
#                     2020-12-01     3194  44.226031
#                     2021-12-01     7909  60.627811
#                     2022-12-01    15913  56.155258
#
# [300 rows x 2 columns]

# %%
overlay = merge_ispa_pm10.groupby(['KABKOT', 'month']).agg({'ispa_5y':'sum', 'pm10':'mean'}).reset_index()
# reset_index() untuk memisahkan kolom KABKOT dan month

# rename columns
overlay = overlay.rename(columns={'ispa_5y': 'sum_ispa', 'pm10':'mean_pm10'})

# %%
overlay
# Out:
#              KABKOT  month  sum_ispa  mean_pm10
# 0     JAKARTA BARAT      1     90839  54.820748
# 1     JAKARTA BARAT      2    108249  58.284398
# 2     JAKARTA BARAT      3    100122  65.689203
# 3     JAKARTA BARAT      4     68004  79.537229
# 4     JAKARTA BARAT      5     59732  87.775776
# 5     JAKARTA BARAT      6     53995  90.324803
# 6     JAKARTA BARAT      7     66370  89.094666
# 7     JAKARTA BARAT      8     73540  85.099615
# 8     JAKARTA BARAT      9     70522  82.619808
# 9     JAKARTA BARAT     10     77470  81.994651
# 10    JAKARTA BARAT     11     76085  71.171407
# 11    JAKARTA BARAT     12     75517  58.058233
# 12    JAKARTA PUSAT      1     66432  56.956311
# 13    JAKARTA PUSAT      2     69706  60.143347
# 14    JAKARTA PUSAT      3     68600  68.406327
# 15    JAKARTA PUSAT      4     57681  81.652127
# 16    JAKARTA PUSAT      5     38394  89.382064
# 17    JAKARTA PUSAT      6     47189  91.474187
# 18    JAKARTA PUSAT      7     39879  89.686927
# 19    JAKARTA PUSAT      8     48124  85.340752
# 20    JAKARTA PUSAT      9     52110  83.144665
# 21    JAKARTA PUSAT     10     56184  82.818730
# 22    JAKARTA PUSAT     11     53971  72.915547
# 23    JAKARTA PUSAT     12     55645  60.314756
# 24  JAKARTA SELATAN      1    106278  58.780765
# 25  JAKARTA SELATAN      2    119348  62.682371
# 26  JAKARTA SELATAN      3    113516  70.917246
# 27  JAKARTA SELATAN      4     83689  85.784375
# 28  JAKARTA SELATAN      5     64125  94.724891
# 29  JAKARTA SELATAN      6     67356  96.761875
# 30  JAKARTA SELATAN      7     77288  95.213701
# 31  JAKARTA SELATAN      8     81335  90.019203
# 32  JAKARTA SELATAN      9     79815  86.698146
# 33  JAKARTA SELATAN     10     76941  85.177124
# 34  JAKARTA SELATAN     11     89080  74.967761
# 35  JAKARTA SELATAN     12     85025  61.987857
# 36    JAKARTA TIMUR      1    123265  58.599203
# 37    JAKARTA TIMUR      2    158365  61.636611
# 38    JAKARTA TIMUR      3    131222  70.300092
# 39    JAKARTA TIMUR      4     88598  83.247013
# 40    JAKARTA TIMUR      5    214623  90.793288
# 41    JAKARTA TIMUR      6     17584  92.473735
# 42    JAKARTA TIMUR      7     92707  90.329499
# 43    JAKARTA TIMUR      8    117612  85.434753
# 44    JAKARTA TIMUR      9    109955  83.109332
# 45    JAKARTA TIMUR     10    128686  82.739552
# 46    JAKARTA TIMUR     11    121594  73.687261
# 47    JAKARTA TIMUR     12    109806  61.715367
# 48    JAKARTA UTARA      1     72042  54.458266
# 49    JAKARTA UTARA      2     92214  56.914749
# 50    JAKARTA UTARA      3     85883  64.881817
# 51    JAKARTA UTARA      4     60416  76.446954
# 52    JAKARTA UTARA      5     48798  83.006179
# 53    JAKARTA UTARA      6     49345  85.126358
# 54    JAKARTA UTARA      7     56893  83.181407
# 55    JAKARTA UTARA      8     59786  79.558867
# 56    JAKARTA UTARA      9     66534  78.268015
# 57    JAKARTA UTARA     10     69232  79.099616
# 58    JAKARTA UTARA     11     74014  69.705743
# 59    JAKARTA UTARA     12     67350  57.704309

# %% [markdown]
# Rename month for month_name

# %%
import calendar

# Format for monthly graph
overlay['month'] = pd.to_datetime(overlay['month'], format='%m').dt.month_name()

# Set the ['month_name'] as an index
overlay= overlay.set_index('month').reset_index()

# %% [markdown]
# Plot ISPA x t2m

# %%
indicators = ['sum_ispa', 'mean_pm10']

# Group data by KABKOT
grouped_data = overlay.groupby('KABKOT')

# Plot time series for 'tb' and 'pm2p5' for each KABKOT
fig, axs = plt.subplots(len(grouped_data), 1, figsize=(25, len(grouped_data)*5), sharex=False)


for (name, group), ax in zip(grouped_data, axs):
    x = group['month']
    y1 = group['sum_ispa']
    y2 = group['mean_pm10']

    ax.plot(x, y1, label='Kejadian ISPA', marker='o', linewidth=3.5, color='darkcyan')
    ax.set_ylabel(f'{name} - Jumlah Kejadian ISPA (jiwa)', color='darkcyan', weight='bold')
    ax.tick_params(axis='y', labelcolor='darkcyan')

    ax2 = ax.twinx()
    ax2.plot(x, y2, label='PM 10', marker='o',linewidth=3.5, color='brown')
    ax2.set_ylabel(f'{name} - Rata-Rata Konsentrasi PM10 (µg/m³)', color='brown', weight='bold')
    ax2.tick_params(axis='y', labelcolor='brown')

    ax.legend(loc= 'upper left', fontsize=16)
    ax2.legend(loc= 'upper right', fontsize=16)

# Add common x-axis label
axs[-1].set_xlabel('Month', fontsize= 14)
axs[-1].set_title('JAKARTA UTARA', weight='bold', fontsize= 14)
axs[-2].set_title('JAKARTA TIMUR', weight='bold', fontsize= 14)
axs[-3].set_title('JAKARTA SELATAN', weight='bold', fontsize= 14)
axs[-4].set_title('JAKARTA PUSAT', weight='bold', fontsize= 14)
axs[-5].set_title('JAKARTA BARAT', weight='bold', fontsize= 14)

plt.tight_layout()
plt.show()
