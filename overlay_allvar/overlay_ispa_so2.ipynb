# %%
# Import module
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# Sort by Month (ISPA)

# %%
# Add csv file
df_ispa = pd.read_csv('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/overlay_allvar/allvar_ispa_all.csv')
df_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  300 non-null    int64
#  1   Unnamed: 0    300 non-null    int64
#  2   KABKOT        300 non-null    object
#  3   month         300 non-null    int64
#  4   year          300 non-null    int64
#  5   longitude     300 non-null    float64
#  6   latitude      300 non-null    float64
#  7   pm2p5         300 non-null    float64
#  8   time          300 non-null    object
#  9   RH            300 non-null    float64
#  10  t2m           300 non-null    float64
#  11  tp            300 non-null    float64
#  12  ispa          300 non-null    int64
#  13  pm10          300 non-null    float64
#  14  so2           300 non-null    float64
#  15  ispa_balita   300 non-null    int64
#  16  ispa_5y       300 non-null    int64
# dtypes: float64(8), int64(7), object(2)
# memory usage: 40.0+ KB

# %%
# Drop the columns
df_ispa = df_ispa.drop(['Unnamed: 0', 'RH', 'so2', 'pm10', 'pm2p5', 'tp', 't2m'], axis=1)

# %%
df_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  300 non-null    int64
#  1   KABKOT        300 non-null    object
#  2   month         300 non-null    int64
#  3   year          300 non-null    int64
#  4   longitude     300 non-null    float64
#  5   latitude      300 non-null    float64
#  6   time          300 non-null    object
#  7   ispa          300 non-null    int64
#  8   ispa_balita   300 non-null    int64
#  9   ispa_5y       300 non-null    int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 23.6+ KB

# %%
# Filter for years 2018-2022
data_ispa = df_ispa[(df_ispa['year'] >= 2018) & (df_ispa['year'] <= 2022)]

# Group sum_ispa by KABKOT, month, and time
ispa_sort = data_ispa.groupby(['KABKOT', 'month', 'time'])['ispa_5y'].sum()
ispa_sort
# Out:
# KABKOT         month  time
# JAKARTA BARAT  1      2018-01-01    21514
#                       2019-01-01    21402
#                       2020-01-01    28072
#                       2021-01-01     6443
#                       2022-01-01    13408
#                                     ...
# JAKARTA UTARA  12     2018-12-01    18216
#                       2019-12-01    22118
#                       2020-12-01     3194
#                       2021-12-01     7909
#                       2022-12-01    15913
# Name: ispa_5y, Length: 300, dtype: int64

# %% [markdown]
# Sort by Month (PM10)

# %%
# Add csv file
df_so2= pd.read_csv('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/overlay_allvar/allvar_ispa_all.csv')
df_so2 = df_so2.drop(['Unnamed: 0', 'ispa', 't2m', 'RH', 'pm10', 'pm2p5', 'tp'], axis=1)
df_so2
# Out:
#      Unnamed: 0.1         KABKOT  month  year   longitude  latitude  \
# 0               0  JAKARTA BARAT      1  2018  106.750000 -6.158333
# 1               1  JAKARTA BARAT      2  2018  106.750000 -6.158333
# 2               2  JAKARTA BARAT      3  2018  106.750000 -6.158333
# 3               3  JAKARTA BARAT      4  2018  106.750000 -6.158333
# 4               4  JAKARTA BARAT      5  2018  106.750000 -6.158333
# ..            ...            ...    ...   ...         ...       ...
# 295           295  JAKARTA UTARA      8  2022  106.891667 -6.125000
# 296           296  JAKARTA UTARA      9  2022  106.891667 -6.125000
# 297           297  JAKARTA UTARA     10  2022  106.891667 -6.125000
# 298           298  JAKARTA UTARA     11  2022  106.891667 -6.125000
# 299           299  JAKARTA UTARA     12  2022  106.891667 -6.125000
#
#            time       so2  ispa_balita  ispa_5y
# 0    2018-01-01  3.282244        13522    21514
# 1    2018-02-01  3.608457        12937    23476
# 2    2018-03-01  4.557899        12937    27114
# 3    2018-04-01  5.501254        10849    22222
# 4    2018-05-01  6.098758         9575    22691
# ..          ...       ...          ...      ...
# 295  2022-08-01  5.413889         6287    17425
# 296  2022-09-01  5.163605         7962    21946
# 297  2022-10-01  4.771141         8871    22766
# 298  2022-11-01  4.642301        10906    25861
# 299  2022-12-01  3.910819         9731    15913
#
# [300 rows x 10 columns]

# %%
# Filter for years 2018-2022
data_so2= df_so2[(df_so2['year'] >= 2018) & (df_so2['year'] <= 2022)]

# Group mean_RH by KABKOT, month, and time
so2_sort = data_so2.groupby(['KABKOT', 'month', 'time'])['so2'].mean()
so2_sort
# Out:
# KABKOT         month  time
# JAKARTA BARAT  1      2018-01-01    3.282244
#                       2019-01-01    3.794546
#                       2020-01-01    3.886676
#                       2021-01-01    3.883337
#                       2022-01-01    4.047353
#                                       ...
# JAKARTA UTARA  12     2018-12-01    3.804287
#                       2019-12-01    4.079590
#                       2020-12-01    3.382975
#                       2021-12-01    4.220228
#                       2022-12-01    3.910819
# Name: so2, Length: 300, dtype: float64

# %% [markdown]
# Merge ISPA and pm2p5 (sorted)

# %%
merge_ispa_so2 = pd.merge(ispa_sort, so2_sort, on=['KABKOT','month','time'])
merge_ispa_so2
# Out:
#                                 ispa_5y       so2
# KABKOT        month time
# JAKARTA BARAT 1     2018-01-01    21514  3.282244
#                     2019-01-01    21402  3.794546
#                     2020-01-01    28072  3.886676
#                     2021-01-01     6443  3.883337
#                     2022-01-01    13408  4.047353
# ...                                 ...       ...
# JAKARTA UTARA 12    2018-12-01    18216  3.804287
#                     2019-12-01    22118  4.079590
#                     2020-12-01     3194  3.382975
#                     2021-12-01     7909  4.220228
#                     2022-12-01    15913  3.910819
#
# [300 rows x 2 columns]

# %%
overlay = merge_ispa_so2.groupby(['KABKOT', 'month']).agg({'ispa_5y':'sum', 'so2':'mean'}).reset_index()
# reset_index() untuk memisahkan kolom KABKOT dan month

# rename columns
overlay = overlay.rename(columns={'ispa_5y': 'sum_ispa', 'so2':'mean_so2'})

# %%
overlay
# Out:
#              KABKOT  month  sum_ispa  mean_so2
# 0     JAKARTA BARAT      1     90839  3.778831
# 1     JAKARTA BARAT      2    108249  3.644597
# 2     JAKARTA BARAT      3    100122  4.809099
# 3     JAKARTA BARAT      4     68004  5.641621
# 4     JAKARTA BARAT      5     59732  6.278780
# 5     JAKARTA BARAT      6     53995  6.101910
# 6     JAKARTA BARAT      7     66370  6.215066
# 7     JAKARTA BARAT      8     73540  5.452665
# 8     JAKARTA BARAT      9     70522  5.189886
# 9     JAKARTA BARAT     10     77470  4.954241
# 10    JAKARTA BARAT     11     76085  4.650115
# 11    JAKARTA BARAT     12     75517  4.032931
# 12    JAKARTA PUSAT      1     66432  3.927342
# 13    JAKARTA PUSAT      2     69706  3.756289
# 14    JAKARTA PUSAT      3     68600  4.974725
# 15    JAKARTA PUSAT      4     57681  5.773545
# 16    JAKARTA PUSAT      5     38394  6.403237
# 17    JAKARTA PUSAT      6     47189  6.198587
# 18    JAKARTA PUSAT      7     39879  6.295817
# 19    JAKARTA PUSAT      8     48124  5.489995
# 20    JAKARTA PUSAT      9     52110  5.242907
# 21    JAKARTA PUSAT     10     56184  5.023654
# 22    JAKARTA PUSAT     11     53971  4.774454
# 23    JAKARTA PUSAT     12     55645  4.182337
# 24  JAKARTA SELATAN      1    106278  4.169020
# 25  JAKARTA SELATAN      2    119348  4.014433
# 26  JAKARTA SELATAN      3    113516  5.271046
# 27  JAKARTA SELATAN      4     83689  6.189136
# 28  JAKARTA SELATAN      5     64125  6.888707
# 29  JAKARTA SELATAN      6     67356  6.673305
# 30  JAKARTA SELATAN      7     77288  6.774193
# 31  JAKARTA SELATAN      8     81335  5.889701
# 32  JAKARTA SELATAN      9     79815  5.561820
# 33  JAKARTA SELATAN     10     76941  5.299851
# 34  JAKARTA SELATAN     11     89080  5.030011
# 35  JAKARTA SELATAN     12     85025  4.409892
# 36    JAKARTA TIMUR      1    123265  4.043746
# 37    JAKARTA TIMUR      2    158365  3.845463
# 38    JAKARTA TIMUR      3    131222  5.090001
# 39    JAKARTA TIMUR      4     88598  5.887414
# 40    JAKARTA TIMUR      5    214623  6.530113
# 41    JAKARTA TIMUR      6     17584  6.306474
# 42    JAKARTA TIMUR      7     92707  6.389919
# 43    JAKARTA TIMUR      8    117612  5.526211
# 44    JAKARTA TIMUR      9    109955  5.264880
# 45    JAKARTA TIMUR     10    128686  5.046980
# 46    JAKARTA TIMUR     11    121594  4.847773
# 47    JAKARTA TIMUR     12    109806  4.283528
# 48    JAKARTA UTARA      1     72042  3.622773
# 49    JAKARTA UTARA      2     92214  3.438057
# 50    JAKARTA UTARA      3     85883  4.592327
# 51    JAKARTA UTARA      4     60416  5.278994
# 52    JAKARTA UTARA      5     48798  5.838940
# 53    JAKARTA UTARA      6     49345  5.652491
# 54    JAKARTA UTARA      7     56893  5.741937
# 55    JAKARTA UTARA      8     59786  5.007531
# 56    JAKARTA UTARA      9     66534  4.825814
# 57    JAKARTA UTARA     10     69232  4.648806
# 58    JAKARTA UTARA     11     74014  4.432520
# 59    JAKARTA UTARA     12     67350  3.879580

# %% [markdown]
# Rename month for month_name

# %%
import calendar

# Format for monthly graph
overlay['month'] = pd.to_datetime(overlay['month'], format='%m').dt.month_name()

# Set the ['month_name'] as an index
overlay= overlay.set_index('month').reset_index()

# %% [markdown]
# Plot ISPA x t2m

# %%
indicators = ['sum_ispa', 'mean_so2']

# Group data by KABKOT
grouped_data = overlay.groupby('KABKOT')

# Plot time series for 'tb' and 'pm2p5' for each KABKOT
fig, axs = plt.subplots(len(grouped_data), 1, figsize=(25, len(grouped_data)*5), sharex=False)


for (name, group), ax in zip(grouped_data, axs):
    x = group['month']
    y1 = group['sum_ispa']
    y2 = group['mean_so2']

    ax.plot(x, y1, label='Kejadian ISPA', marker='o', linewidth=3.5, color='darkcyan')
    ax.set_ylabel(f'{name} - Jumlah Kejadian ISPA (jiwa)', color='darkcyan', weight='bold')
    ax.tick_params(axis='y', labelcolor='darkcyan')

    ax2 = ax.twinx()
    ax2.plot(x, y2, label='SO2', marker='o',linewidth=3.5, color='brown')
    ax2.set_ylabel(f'{name} - Rata-Rata Konsentrasi SO2 (µg/m³)', color='brown', weight='bold')
    ax2.tick_params(axis='y', labelcolor='brown')

    ax.legend(loc= 'upper left', fontsize=16)
    ax2.legend(loc= 'upper right', fontsize=16)

# Add common x-axis label
axs[-1].set_xlabel('Month', fontsize= 14)
axs[-1].set_title('JAKARTA UTARA', weight='bold', fontsize= 14)
axs[-2].set_title('JAKARTA TIMUR', weight='bold', fontsize= 14)
axs[-3].set_title('JAKARTA SELATAN', weight='bold', fontsize= 14)
axs[-4].set_title('JAKARTA PUSAT', weight='bold', fontsize= 14)
axs[-5].set_title('JAKARTA BARAT', weight='bold', fontsize= 14)

plt.tight_layout()
plt.show()
