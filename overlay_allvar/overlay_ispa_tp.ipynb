# %%
# Import module
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# Sort by Month (ISPA)

# %%
# Add csv file
df_ispa = pd.read_csv('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/overlay_allvar/allvar_ispa_all.csv')
df_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  300 non-null    int64
#  1   Unnamed: 0    300 non-null    int64
#  2   KABKOT        300 non-null    object
#  3   month         300 non-null    int64
#  4   year          300 non-null    int64
#  5   longitude     300 non-null    float64
#  6   latitude      300 non-null    float64
#  7   pm2p5         300 non-null    float64
#  8   time          300 non-null    object
#  9   RH            300 non-null    float64
#  10  t2m           300 non-null    float64
#  11  tp            300 non-null    float64
#  12  ispa          300 non-null    int64
#  13  pm10          300 non-null    float64
#  14  so2           300 non-null    float64
#  15  ispa_balita   300 non-null    int64
#  16  ispa_5y       300 non-null    int64
# dtypes: float64(8), int64(7), object(2)
# memory usage: 40.0+ KB

# %%
# Drop the columns
df_ispa = df_ispa.drop(['Unnamed: 0', 'RH', 'Unnamed: 0.1', 'tp', 't2m'], axis=1)

# %%
df_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   KABKOT       300 non-null    object
#  1   month        300 non-null    int64
#  2   year         300 non-null    int64
#  3   longitude    300 non-null    float64
#  4   latitude     300 non-null    float64
#  5   pm2p5        300 non-null    float64
#  6   time         300 non-null    object
#  7   ispa         300 non-null    int64
#  8   pm10         300 non-null    float64
#  9   so2          300 non-null    float64
#  10  ispa_balita  300 non-null    int64
#  11  ispa_5y      300 non-null    int64
# dtypes: float64(5), int64(5), object(2)
# memory usage: 28.3+ KB

# %%
# Filter for years 2018-2022
data_ispa = df_ispa[(df_ispa['year'] >= 2018) & (df_ispa['year'] <= 2022)]

# Group sum_ispa by KABKOT, month, and time
ispa_sort = data_ispa.groupby(['KABKOT', 'month', 'time'])['ispa_5y'].sum()
ispa_sort
# Out:
# KABKOT         month  time
# JAKARTA BARAT  1      2018-01-01    21514
#                       2019-01-01    21402
#                       2020-01-01    28072
#                       2021-01-01     6443
#                       2022-01-01    13408
#                                     ...
# JAKARTA UTARA  12     2018-12-01    18216
#                       2019-12-01    22118
#                       2020-12-01     3194
#                       2021-12-01     7909
#                       2022-12-01    15913
# Name: ispa_5y, Length: 300, dtype: int64

# %% [markdown]
# Sort by Month (tp)

# %%
# Add csv file
df_tp = pd.read_csv('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/overlay_allvar/allvar_ispa_all.csv')
df_tp = df_tp.drop(['Unnamed: 0', 'ispa_5y', 'Unnamed: 0.1', 't2m', 'RH'], axis=1)
df_tp
# Out:
#             KABKOT  month  year   longitude  latitude      pm2p5        time  \
# 0    JAKARTA BARAT      1  2018  106.750000 -6.158333  32.990347  2018-01-01
# 1    JAKARTA BARAT      2  2018  106.750000 -6.158333  39.145521  2018-02-01
# 2    JAKARTA BARAT      3  2018  106.750000 -6.158333  44.443065  2018-03-01
# 3    JAKARTA BARAT      4  2018  106.750000 -6.158333  61.214024  2018-04-01
# 4    JAKARTA BARAT      5  2018  106.750000 -6.158333  68.229752  2018-05-01
# ..             ...    ...   ...         ...       ...        ...         ...
# 295  JAKARTA UTARA      8  2022  106.891667 -6.125000  60.172357  2022-08-01
# 296  JAKARTA UTARA      9  2022  106.891667 -6.125000  61.185956  2022-09-01
# 297  JAKARTA UTARA     10  2022  106.891667 -6.125000  49.726068  2022-10-01
# 298  JAKARTA UTARA     11  2022  106.891667 -6.125000  46.806576  2022-11-01
# 299  JAKARTA UTARA     12  2022  106.891667 -6.125000  39.195320  2022-12-01
#
#            tp   ispa       pm10       so2  ispa_balita
# 0    7.256567  35036  47.294950  3.282244        13522
# 1    9.965402  36413  55.981318  3.608457        12937
# 2    7.343809  40051  63.225958  4.557899        12937
# 3    6.208611  33071  86.887396  5.501254        10849
# 4    2.895800  32266  96.986573  6.098758         9575
# ..        ...    ...        ...       ...          ...
# 295  2.435247  23712  85.524501  5.413889         6287
# 296  4.522162  29908  87.035939  5.163605         7962
# 297  8.589306  31637  70.626910  4.771141         8871
# 298  5.543476  36767  66.740500  4.642301        10906
# 299  7.970700  25644  56.155258  3.910819         9731
#
# [300 rows x 12 columns]

# %%
# Filter for years 2018-2022
data_tp = df_tp[(df_tp['year'] >= 2018) & (df_tp['year'] <= 2022)]

# Group mean_RH by KABKOT, month, and time
tp_sort = data_tp.groupby(['KABKOT', 'month', 'time'])['tp'].mean()
tp_sort
# Out:
# KABKOT         month  time
# JAKARTA BARAT  1      2018-01-01     7.256567
#                       2019-01-01     7.881096
#                       2020-01-01    14.475730
#                       2021-01-01    10.499982
#                       2022-01-01     6.211204
#                                       ...
# JAKARTA UTARA  12     2018-12-01     5.350711
#                       2019-12-01    10.058320
#                       2020-12-01     9.142884
#                       2021-12-01     8.356443
#                       2022-12-01     7.970700
# Name: tp, Length: 300, dtype: float64

# %% [markdown]
# Merge ISPA and tp (sorted)

# %%
merge_ispa_tp = pd.merge(ispa_sort, tp_sort, on=['KABKOT','month','time'])
merge_ispa_tp
# Out:
#                                 ispa_5y         tp
# KABKOT        month time
# JAKARTA BARAT 1     2018-01-01    21514   7.256567
#                     2019-01-01    21402   7.881096
#                     2020-01-01    28072  14.475730
#                     2021-01-01     6443  10.499982
#                     2022-01-01    13408   6.211204
# ...                                 ...        ...
# JAKARTA UTARA 12    2018-12-01    18216   5.350711
#                     2019-12-01    22118  10.058320
#                     2020-12-01     3194   9.142884
#                     2021-12-01     7909   8.356443
#                     2022-12-01    15913   7.970700
#
# [300 rows x 2 columns]

# %%
overlay = merge_ispa_tp.groupby(['KABKOT', 'month']).agg({'ispa_5y':'sum', 'tp':'mean'}).reset_index()
# reset_index() untuk memisahkan kolom KABKOT dan month

# rename columns
overlay = overlay.rename(columns={'ispa_5y': 'sum_ispa', 'tp':'mean_tp'})

# %%
overlay
# Out:
#              KABKOT  month  sum_ispa    mean_tp
# 0     JAKARTA BARAT      1     90839   9.264916
# 1     JAKARTA BARAT      2    108249  10.695420
# 2     JAKARTA BARAT      3    100122   7.989386
# 3     JAKARTA BARAT      4     68004   6.768114
# 4     JAKARTA BARAT      5     59732   3.957347
# 5     JAKARTA BARAT      6     53995   3.124164
# 6     JAKARTA BARAT      7     66370   1.948042
# 7     JAKARTA BARAT      8     73540   2.150414
# 8     JAKARTA BARAT      9     70522   2.775767
# 9     JAKARTA BARAT     10     77470   4.446980
# 10    JAKARTA BARAT     11     76085   5.661228
# 11    JAKARTA BARAT     12     75517   8.068726
# 12    JAKARTA PUSAT      1     66432   9.626161
# 13    JAKARTA PUSAT      2     69706  11.172359
# 14    JAKARTA PUSAT      3     68600   8.444507
# 15    JAKARTA PUSAT      4     57681   7.150132
# 16    JAKARTA PUSAT      5     38394   3.940211
# 17    JAKARTA PUSAT      6     47189   3.066727
# 18    JAKARTA PUSAT      7     39879   1.797349
# 19    JAKARTA PUSAT      8     48124   2.093010
# 20    JAKARTA PUSAT      9     52110   2.708095
# 21    JAKARTA PUSAT     10     56184   4.755655
# 22    JAKARTA PUSAT     11     53971   6.440136
# 23    JAKARTA PUSAT     12     55645   8.375961
# 24  JAKARTA SELATAN      1    106278   9.639708
# 25  JAKARTA SELATAN      2    119348  10.985248
# 26  JAKARTA SELATAN      3    113516   8.769002
# 27  JAKARTA SELATAN      4     83689   7.474538
# 28  JAKARTA SELATAN      5     64125   4.063996
# 29  JAKARTA SELATAN      6     67356   3.169355
# 30  JAKARTA SELATAN      7     77288   1.924254
# 31  JAKARTA SELATAN      8     81335   2.416731
# 32  JAKARTA SELATAN      9     79815   3.147362
# 33  JAKARTA SELATAN     10     76941   5.367697
# 34  JAKARTA SELATAN     11     89080   6.985544
# 35  JAKARTA SELATAN     12     85025   8.764671
# 36    JAKARTA TIMUR      1    123265  10.028131
# 37    JAKARTA TIMUR      2    158365  11.573100
# 38    JAKARTA TIMUR      3    131222   9.167427
# 39    JAKARTA TIMUR      4     88598   7.740387
# 40    JAKARTA TIMUR      5    214623   4.121089
# 41    JAKARTA TIMUR      6     17584   3.182487
# 42    JAKARTA TIMUR      7     92707   1.765703
# 43    JAKARTA TIMUR      8    117612   2.183894
# 44    JAKARTA TIMUR      9    109955   2.930892
# 45    JAKARTA TIMUR     10    128686   5.413112
# 46    JAKARTA TIMUR     11    121594   7.529147
# 47    JAKARTA TIMUR     12    109806   8.886482
# 48    JAKARTA UTARA      1     72042   9.644275
# 49    JAKARTA UTARA      2     92214  11.400957
# 50    JAKARTA UTARA      3     85883   8.154170
# 51    JAKARTA UTARA      4     60416   6.915590
# 52    JAKARTA UTARA      5     48798   3.982823
# 53    JAKARTA UTARA      6     49345   3.105375
# 54    JAKARTA UTARA      7     56893   1.742494
# 55    JAKARTA UTARA      8     59786   1.864948
# 56    JAKARTA UTARA      9     66534   2.533138
# 57    JAKARTA UTARA     10     69232   4.379896
# 58    JAKARTA UTARA     11     74014   6.028470
# 59    JAKARTA UTARA     12     67350   8.175812

# %% [markdown]
# Rename month for month_name

# %%
import calendar

# Format for monthly graph
overlay['month'] = pd.to_datetime(overlay['month'], format='%m').dt.month_name()

# Set the ['month_name'] as an index
overlay= overlay.set_index('month').reset_index()

# %% [markdown]
# Plot ISPA x t2m

# %%
indicators = ['sum_ispa', 'mean_tp']

# Group data by KABKOT
grouped_data = overlay.groupby('KABKOT')

# Plot time series for 'tb' and 'pm2p5' for each KABKOT
fig, axs = plt.subplots(len(grouped_data), 1, figsize=(25, len(grouped_data)*5), sharex=False)


for (name, group), ax in zip(grouped_data, axs):
    x = group['month']
    y1 = group['sum_ispa']
    y2 = group['mean_tp']

    ax.plot(x, y1, label='Kejadian ISPA', marker='o', linewidth=3.5, color='darkcyan')
    ax.set_ylabel(f'{name} - Jumlah Kejadian ISPA (jiwa)', color='darkcyan', weight='bold')
    ax.tick_params(axis='y', labelcolor='darkcyan')

    ax2 = ax.twinx()
    ax2.plot(x, y2, label='Curah Hujan (mm)', marker='o',linewidth=3.5, color='brown')
    ax2.set_ylabel(f'{name} - Rata-Rata Curah Hujan (mm)', color='brown', weight='bold')
    ax2.tick_params(axis='y', labelcolor='brown')

    ax.legend(loc= 'upper left', fontsize=16)
    ax2.legend(loc= 'upper right', fontsize=16)

# Add common x-axis label
axs[-1].set_xlabel('Month', fontsize= 14)
axs[-1].set_title('JAKARTA UTARA', weight='bold', fontsize= 14)
axs[-2].set_title('JAKARTA TIMUR', weight='bold', fontsize= 14)
axs[-3].set_title('JAKARTA SELATAN', weight='bold', fontsize= 14)
axs[-4].set_title('JAKARTA PUSAT', weight='bold', fontsize= 14)
axs[-5].set_title('JAKARTA BARAT', weight='bold', fontsize= 14)

plt.tight_layout()
plt.show()
