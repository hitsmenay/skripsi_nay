# %%
import geopandas as gpd
import pandas as pd

# %%
# Total Precipitation preparation
# Load CSV
df_csv = pd.read_csv('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/iklim/suhu/nc_to_csv/temp_satuan_kec.csv')
tp_mean = df_csv.groupby(['longitude', 'latitude'], as_index=False)['t2m'].mean()

# %%
# Load shapefile into a GeoDataFrame
gdf_shapefile = gpd.read_file(r"/Users/roniabuhanif/Downloads/BMKG/data_skripsi/petadki_kecamatan_2/kecamatan/Kecamatan-DKI-Jakarta-polygon.shp")

# %%
# Convert DataFrame to GeoDataFrame
geometry = gpd.points_from_xy(tp_mean['longitude'], tp_mean['latitude'])
gdf_csv = gpd.GeoDataFrame(tp_mean, geometry=geometry, crs=4326)

# %%
gdf_csv.plot()
gdf_shapefile.plot()
# Out:
# <Axes: >

# %%
# spatial join
result = gpd.sjoin(gdf_csv, gdf_shapefile, how='inner', predicate='intersects')
result_pop = result[['longitude', 'latitude', 't2m', 'name', 'geometry']]

# %%
result_pop.plot()
result_pop.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 529 entries, 7620 to 14640
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   longitude  529 non-null    float64
#  1   latitude   529 non-null    float64
#  2   t2m        529 non-null    float64
#  3   name       529 non-null    object
#  4   geometry   529 non-null    geometry
# dtypes: float64(3), geometry(1), object(1)
# memory usage: 24.8+ KB

# %%
dissolved_result = result_pop.dissolve(by='name', aggfunc='mean')
dissolved_result.head(40
                      )
# Out:
#                                                                    geometry  \
# name
# Cakung                    MULTIPOINT ((106.91000 -6.21000), (106.91000 -...
# Cempaka Putih             MULTIPOINT ((106.86000 -6.19000), (106.86000 -...
# Cengkareng                MULTIPOINT ((106.71000 -6.18000), (106.72000 -...
# Cilandak                  MULTIPOINT ((106.77000 -6.29000), (106.78000 -...
# Cilincing                 MULTIPOINT ((106.91000 -6.10000), (106.92000 -...
# Cipayung                  MULTIPOINT ((106.89000 -6.34000), (106.89000 -...
# Ciracas                   MULTIPOINT ((106.87000 -6.35000), (106.87000 -...
# Duren Sawit               MULTIPOINT ((106.90000 -6.24000), (106.90000 -...
# Gambir                    MULTIPOINT ((106.81000 -6.18000), (106.81000 -...
# Grogol Petamburan         MULTIPOINT ((106.77000 -6.16000), (106.78000 -...
# Jagakarsa                 MULTIPOINT ((106.80000 -6.36000), (106.80000 -...
# Jatinegara                MULTIPOINT ((106.87000 -6.24000), (106.87000 -...
# Johar Baru                                       POINT (106.85000 -6.18000)
# Kalideres                 MULTIPOINT ((106.69000 -6.17000), (106.69000 -...
# Kebayoran Baru            MULTIPOINT ((106.79000 -6.26000), (106.79000 -...
# Kebayoran Lama            MULTIPOINT ((106.77000 -6.28000), (106.77000 -...
# Kebon Jeruk               MULTIPOINT ((106.76000 -6.19000), (106.76000 -...
# Kelapa Gading             MULTIPOINT ((106.89000 -6.17000), (106.89000 -...
# Kemayoran                 MULTIPOINT ((106.84000 -6.16000), (106.85000 -...
# Kembangan                 MULTIPOINT ((106.72000 -6.22000), (106.72000 -...
# Kepulauan Seribu Selatan  MULTIPOINT ((106.50000 -5.80000), (106.55000 -...
# Koja                      MULTIPOINT ((106.90000 -6.13000), (106.90000 -...
# Kramat Jati               MULTIPOINT ((106.86000 -6.29000), (106.86000 -...
# Makasar                   MULTIPOINT ((106.88000 -6.29000), (106.88000 -...
# Mampang Prapatan          MULTIPOINT ((106.81000 -6.25000), (106.82000 -...
# Matraman                  MULTIPOINT ((106.86000 -6.21000), (106.86000 -...
# Menteng                   MULTIPOINT ((106.83000 -6.20000), (106.83000 -...
# Pademangan                MULTIPOINT ((106.82000 -6.13000), (106.82000 -...
# Palmerah                  MULTIPOINT ((106.79000 -6.20000), (106.79000 -...
# Pancoran                  MULTIPOINT ((106.83000 -6.27000), (106.83000 -...
# Pasar Minggu              MULTIPOINT ((106.81000 -6.31000), (106.81000 -...
# Pasar Rebo                MULTIPOINT ((106.84000 -6.32000), (106.85000 -...
# Penjaringan               MULTIPOINT ((106.72000 -6.10000), (106.73000 -...
# Pesanggrahan              MULTIPOINT ((106.75000 -6.25000), (106.75000 -...
# Pulo Gadung               MULTIPOINT ((106.88000 -6.21000), (106.88000 -...
# Sawah Besar               MULTIPOINT ((106.83000 -6.17000), (106.83000 -...
# Senen                     MULTIPOINT ((106.84000 -6.18000), (106.85000 -...
# Setiabudi                 MULTIPOINT ((106.82000 -6.23000), (106.82000 -...
# Taman Sari                MULTIPOINT ((106.82000 -6.15000), (106.82000 -...
# Tambora                   MULTIPOINT ((106.80000 -6.16000), (106.80000 -...
#
#                            longitude  latitude        t2m
# name
# Cakung                    106.942813 -6.188125  27.489216
# Cempaka Putih             106.866000 -6.182000  27.510185
# Cengkareng                106.734762 -6.150952  27.588824
# Cilandak                  106.792857 -6.292143  27.142655
# Cilincing                 106.943714 -6.127714  27.598609
# Cipayung                  106.903478 -6.324783  26.921056
# Ciracas                   106.877692 -6.333077  26.872266
# Duren Sawit               106.923333 -6.231667  27.414053
# Gambir                    106.818333 -6.173333  27.530411
# Grogol Petamburan         106.785000 -6.165000  27.547353
# Jagakarsa                 106.821053 -6.334737  26.867221
# Jatinegara                106.878571 -6.227143  27.431175
# Johar Baru                106.850000 -6.180000  27.515591
# Kalideres                 106.702500 -6.133333  27.649240
# Kebayoran Baru            106.800000 -6.246000  27.402604
# Kebayoran Lama            106.780625 -6.247500  27.376666
# Kebon Jeruk               106.769231 -6.190000  27.510336
# Kelapa Gading             106.905000 -6.162143  27.539867
# Kemayoran                 106.856000 -6.162000  27.545033
# Kembangan                 106.741739 -6.197391  27.509412
# Kepulauan Seribu Selatan  106.525000 -5.810000  27.598037
# Koja                      106.906667 -6.120000  27.613834
# Kramat Jati               106.867000 -6.275000  27.237831
# Makasar                   106.891667 -6.263333  27.300611
# Mampang Prapatan          106.821429 -6.251429  27.382944
# Matraman                  106.865000 -6.205000  27.471361
# Menteng                   106.835000 -6.195000  27.492813
# Pademangan                106.842000 -6.133000  27.594395
# Palmerah                  106.796000 -6.192000  27.503467
# Pancoran                  106.842857 -6.257143  27.355243
# Pasar Minggu              106.830000 -6.292632  27.133236
# Pasar Rebo                106.857000 -6.326000  26.918879
# Penjaringan               106.769032 -6.119677  27.622815
# Pesanggrahan              106.759000 -6.250000  27.390788
# Pulo Gadung               106.889231 -6.193077  27.487937
# Sawah Besar               106.833333 -6.156667  27.556037
# Senen                     106.847500 -6.185000  27.507563
# Setiabudi                 106.830000 -6.220000  27.452662
# Taman Sari                106.820000 -6.145000  27.576191
# Tambora                   106.806000 -6.152000  27.566021

# %%
polygon_result = gpd.sjoin(gdf_shapefile, dissolved_result, how='inner', predicate='intersects')

# %%
polygon_result.plot(column="t2m", legend=True, legend_kwds={"label": "Temperature"})
# Out:
# <Axes: >

# %%
polygon_result.to_file('polygon_t2m_result_kecamatan.shp')
# Out:
# /var/folders/81/vqbnjx_x20zdr2m7bscdvp5r0000gn/T/ipykernel_23272/1850899010.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   polygon_result.to_file('polygon_t2m_result_kecamatan.shp')
