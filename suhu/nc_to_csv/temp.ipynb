# %%
import pandas as pd
import xarray as xr
from netCDF4 import Dataset
import numpy as np

# %%
ds = xr.open_dataset("/Users/roniabuhanif/Downloads/BMKG/data_skripsi/iklim/suhu/2m_temp.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 7, latitude: 7, time: 60)
# Coordinates:
#   * longitude  (longitude) float32 106.0 106.2 106.5 106.8 107.0 107.2 107.5
#   * latitude   (latitude) float32 -5.5 -5.75 -6.0 -6.25 -6.5 -6.75 -7.0
#   * time       (time) datetime64[ns] 2018-01-01 2018-02-01 ... 2022-12-01
# Data variables:
#     t2m        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-11-22 08:41:27 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
latii = [-6.1556594]
lonii = [106.8388152]

new_lon = np.arange(ds.longitude[0], ds.longitude[-1], 0.010)  # 0.4 to 0.05
new_lat = np.arange(ds.latitude[-1], ds.latitude[0], 0.010)
ds = ds.interp(latitude=new_lat, longitude=new_lon)

# %%
# mengubah data menjadi data tipe dataframa
df = ds.to_dataframe()
# konversi kg/m3 menjadi mikrogram/m3
df ["t2m"] = df["t2m"] - 273
# menyimpan dataframe menjadi .csv
df.to_csv("temp_satuan_kec.csv")
