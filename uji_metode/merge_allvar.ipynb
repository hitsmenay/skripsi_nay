# %% [markdown]
# **PER KOTA, 5 TAHUN (2018-2022)**

# %%
import pandas as pd
import xarray as xr
import numpy as np

# %%
df_ispa_climate = pd.read_csv('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/data_kesehatan/ispa_month/data_ispa.csv')
df_pm25 = pd.read_csv("/Users/roniabuhanif/Downloads/BMKG/data_skripsi/kualitas_udara/pm25/polygon_kota/pm25_year/pm25_kabkot_year.csv")
df_pm10= pd.read_csv("/Users/roniabuhanif/Downloads/BMKG/data_skripsi/kualitas_udara/pm10/polygon_kota/pm10_year/pm10_kabkot_year.csv")
df_so2= pd.read_csv("/Users/roniabuhanif/Downloads/BMKG/data_skripsi/kualitas_udara/so2/polygon_kota/so2_year/SO2_kabkot_year.csv")

# %%
df_ku_ispa = df_pm25.merge(df_ispa_climate)

# %%
df_ku_ispa = df_ku_ispa.merge(df_so2)
df_ku_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    300 non-null    int64
#  1   KABKOT        300 non-null    object
#  2   month         300 non-null    int64
#  3   year          300 non-null    int64
#  4   longitude     300 non-null    float64
#  5   latitude      300 non-null    float64
#  6   pm2p5         300 non-null    float64
#  7   time          300 non-null    object
#  8   Unnamed: 0.2  300 non-null    int64
#  9   Unnamed: 0.1  300 non-null    int64
#  10  RH            300 non-null    float64
#  11  t2m           300 non-null    float64
#  12  tp            300 non-null    float64
#  13  ispa          300 non-null    int64
#  14  so2           300 non-null    float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 35.3+ KB

# %%
df_ku_ispa = df_ku_ispa.merge(df_pm10)
df_ku_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    300 non-null    int64
#  1   KABKOT        300 non-null    object
#  2   month         300 non-null    int64
#  3   year          300 non-null    int64
#  4   longitude     300 non-null    float64
#  5   latitude      300 non-null    float64
#  6   pm2p5         300 non-null    float64
#  7   time          300 non-null    object
#  8   Unnamed: 0.2  300 non-null    int64
#  9   Unnamed: 0.1  300 non-null    int64
#  10  RH            300 non-null    float64
#  11  t2m           300 non-null    float64
#  12  tp            300 non-null    float64
#  13  ispa          300 non-null    int64
#  14  so2           300 non-null    float64
#  15  pm10          300 non-null    float64
# dtypes: float64(8), int64(6), object(2)
# memory usage: 37.6+ KB

# %%
# Save format csv seluruh parameter dan kasus ISPA
df_ku_ispa = df_ku_ispa.drop(['Unnamed: 0', 'Unnamed: 0.2', 'Unnamed: 0.1'], axis=1)

# %%
df_ku_ispa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   KABKOT     300 non-null    object
#  1   month      300 non-null    int64
#  2   year       300 non-null    int64
#  3   longitude  300 non-null    float64
#  4   latitude   300 non-null    float64
#  5   pm2p5      300 non-null    float64
#  6   time       300 non-null    object
#  7   RH         300 non-null    float64
#  8   t2m        300 non-null    float64
#  9   tp         300 non-null    float64
#  10  ispa       300 non-null    int64
#  11  so2        300 non-null    float64
#  12  pm10       300 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 30.6+ KB

# %%
df_ku_ispa['time']= pd.to_datetime(df_ku_ispa['time'])
df_ku_ispa.to_csv('allvar_ispa.csv')

# %%
df_ku_ispa.drop(['time'], axis=1)
df_climate= df_ku_ispa.drop(['time'], axis=1)

# %%
df_climate.info()
df_climate.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   KABKOT     300 non-null    object
#  1   month      300 non-null    int64
#  2   year       300 non-null    int64
#  3   longitude  300 non-null    float64
#  4   latitude   300 non-null    float64
#  5   pm2p5      300 non-null    float64
#  6   RH         300 non-null    float64
#  7   t2m        300 non-null    float64
#  8   tp         300 non-null    float64
#  9   ispa       300 non-null    int64
#  10  so2        300 non-null    float64
#  11  pm10       300 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 28.3+ KB
#            month         year   longitude    latitude       pm2p5          RH  \
# count  300.00000   300.000000  300.000000  300.000000  300.000000  300.000000
# mean     6.50000  2020.000000  106.842000   -6.205333   53.862079   80.452865
# std      3.45782     1.416576    0.057980    0.059704    9.734461    4.715435
# min      1.00000  2018.000000  106.750000   -6.283333   30.068709   68.119665
# 25%      3.75000  2019.000000  106.808333   -6.260000   45.978905   78.811463
# 50%      6.50000  2020.000000  106.850000   -6.200000   55.306899   81.855138
# 75%      9.25000  2021.000000  106.891667   -6.158333   61.028492   83.671870
# max     12.00000  2022.000000  106.910000   -6.125000   74.644463   87.242365
#
#               t2m          tp           ispa         so2        pm10
# count  300.000000  300.000000     300.000000  300.000000  300.000000
# mean    27.418990    5.859645   15619.363333   99.751604   76.547326
# std      0.496142    3.713985   15730.819301   18.310268   13.696511
# min     26.095241    0.286658     846.000000   59.944243   43.204622
# 25%     27.094362    2.733340    5044.750000   86.363837   65.270719
# 50%     27.407935    5.544403   10007.000000   99.711803   78.413041
# 75%     27.756224    8.302740   23655.750000  114.302403   86.626805
# max     28.822052   16.167215  149379.000000  137.204694  106.149704

# %%
df_climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   KABKOT     300 non-null    object
#  1   month      300 non-null    int64
#  2   year       300 non-null    int64
#  3   longitude  300 non-null    float64
#  4   latitude   300 non-null    float64
#  5   pm2p5      300 non-null    float64
#  6   RH         300 non-null    float64
#  7   t2m        300 non-null    float64
#  8   tp         300 non-null    float64
#  9   ispa       300 non-null    int64
#  10  so2        300 non-null    float64
#  11  pm10       300 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 28.3+ KB

# %%
city_east = df_climate[df_climate['KABKOT'] == 'JAKARTA TIMUR']
city_south = df_climate[df_climate['KABKOT'] == 'JAKARTA SELATAN']
city_west = df_climate[df_climate['KABKOT'] == 'JAKARTA BARAT']
city_north = df_climate[df_climate['KABKOT'] == 'JAKARTA UTARA']
city_central = df_climate[df_climate['KABKOT'] == 'JAKARTA PUSAT']

# %%
#import modul
import matplotlib.pyplot as plt
import seaborn as sns

# %%
i_east = (city_east.columns[6:])
i_south = (city_south.columns[6:])
i_west = (city_west.columns[6:])
i_north = (city_north.columns[6:])
i_central = (city_central.columns[6:])
print(i_east,i_south,i_west,i_north,i_central)
# Out:
# Index(['RH', 't2m', 'tp', 'ispa', 'so2', 'pm10'], dtype='object') Index(['RH', 't2m', 'tp', 'ispa', 'so2', 'pm10'], dtype='object') Index(['RH', 't2m', 'tp', 'ispa', 'so2', 'pm10'], dtype='object') Index(['RH', 't2m', 'tp', 'ispa', 'so2', 'pm10'], dtype='object') Index(['RH', 't2m', 'tp', 'ispa', 'so2', 'pm10'], dtype='object')

# %%
plt.figure(figsize=(10,5))
plt.title("Variables Correlation")
cmap = sns.diverging_palette(260,-10,s=50, l=50, n=6, as_cmap=True) #pewarnaan
sns.heatmap(city_east[i_east].corr(), square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Variables Correlation")
cmap = sns.diverging_palette(260,-10,s=50, l=50, n=6, as_cmap=True) #pewarnaan
sns.heatmap(city_south[i_south].corr(), square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Variables Correlation")
cmap = sns.diverging_palette(260,-10,s=50, l=50, n=6, as_cmap=True) #pewarnaan
sns.heatmap(city_west[i_west].corr(), square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Variables Correlation")
cmap = sns.diverging_palette(260,-10,s=50, l=50, n=6, as_cmap=True) #pewarnaan
sns.heatmap(city_north[i_north].corr(), square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Variables Correlation")
cmap = sns.diverging_palette(260,-10,s=50, l=50, n=6, as_cmap=True) #pewarnaan
sns.heatmap(city_central[i_central].corr(), square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()
