# %% [markdown]
# __Uji Normalitas PM10__

# %%
import pandas as pd
df = pd.read_csv(r'/Users/roniabuhanif/Downloads/BMKG/data_skripsi/kualitas_udara/pm10/pm10_satuan.csv')

# %%
from scipy.stats import kstest

x = kstest(df['pm10'], "norm") 
x
# Out:
# KstestResult(statistic=0.5000000290287003, pvalue=0.0, statistic_location=7.276416109647282e-08, statistic_sign=-1)

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.hist(df['pm10'])
# Out:
# (array([ 1356.,  5886.,  8758., 10064., 11110.,  8832.,  4795.,  2434.,
#           688.,    77.]),
#  array([7.27641611e-08, 1.03401413e-07, 1.34038665e-07, 1.64675917e-07,
#         1.95313168e-07, 2.25950420e-07, 2.56587672e-07, 2.87224924e-07,
#         3.17862176e-07, 3.48499428e-07, 3.79136679e-07]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# __Uji Normalitas PM2.5__

# %%
import pandas as pd
df = pd.read_csv(r'/Users/roniabuhanif/Downloads/BMKG/data_skripsi/kualitas_udara/pm25/pm25_satuan.csv')

# %%
from scipy.stats import kstest

x = kstest(df['pm2p5'], "norm") 
x
# Out:
# KstestResult(statistic=0.5000000202937097, pvalue=0.0, statistic_location=5.086878651638952e-08, statistic_sign=-1)

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.hist(df['pm2p5'])
# Out:
# (array([ 1460.,  5849.,  8632., 10009., 10965.,  8979.,  4889.,  2454.,
#           686.,    77.]),
#  array([5.08687865e-08, 7.24412567e-08, 9.40137269e-08, 1.15586197e-07,
#         1.37158667e-07, 1.58731138e-07, 1.80303608e-07, 2.01876078e-07,
#         2.23448548e-07, 2.45021018e-07, 2.66593489e-07]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# __Uji Normalitas SO2__

# %%
import pandas as pd
df = pd.read_csv(r'/Users/roniabuhanif/Downloads/BMKG/data_skripsi/kualitas_udara/so2/so2_arrange.csv')

# %%
from scipy.stats import kstest

x = kstest(df['tcso2'], "norm") 
x
# Out:
# KstestResult(statistic=0.5000005783712943, pvalue=0.0, statistic_location=1.4497618394671008e-06, statistic_sign=-1)

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.hist(df['tcso2'])
# Out:
# (array([2823., 8780., 9716., 9370., 8686., 6681., 4018., 2335., 1257.,
#          334.]),
#  array([1.44976184e-06, 2.62244212e-06, 3.79512240e-06, 4.96780268e-06,
#         6.14048296e-06, 7.31316324e-06, 8.48584352e-06, 9.65852380e-06,
#         1.08312041e-05, 1.20038844e-05, 1.31765646e-05]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# __Uji Normalitas Total Precipitation__

# %%
import pandas as pd
df = pd.read_csv(r'/Users/roniabuhanif/Downloads/BMKG/data_skripsi/iklim/curah_hujan/nc_to_csv/tp_satuan.csv')

# %%
from scipy.stats import kstest

x = kstest(df['tp'], "norm") 
x
# Out:
# KstestResult(statistic=0.8200642107752344, pvalue=0.0, statistic_location=1.9166769459844064, statistic_sign=-1)

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.hist(df['tp'])
# Out:
# (array([1.2569e+04, 1.3995e+04, 1.3113e+04, 8.5790e+03, 4.2290e+03,
#         1.2010e+03, 2.0500e+02, 5.9000e+01, 3.8000e+01, 1.2000e+01]),
#  array([ 0.03814697,  3.07674408,  6.11534119,  9.15393829, 12.1925354 ,
#         15.23113251, 18.26972961, 21.30832672, 24.34692383, 27.38552094,
#         30.42411804]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# __Uji Normalitas Temperature__

# %%
import pandas as pd
df = pd.read_csv(r'/Users/roniabuhanif/Downloads/BMKG/data_skripsi/iklim/suhu/nc_to_csv/temp_satuan.csv')

# %%
from scipy.stats import kstest

x = kstest(df['t2m'], "norm") 
x
# Out:
# KstestResult(statistic=1.0, pvalue=0.0, statistic_location=21.35902709960959, statistic_sign=-1)

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.hist(df['t2m'])
# Out:
# (array([   78.,   377.,  1365.,  4068.,  5803.,  6997.,  7831., 18233.,
#          8863.,   385.]),
#  array([21.3590271 , 22.16256531, 22.96610352, 23.76964172, 24.57317993,
#         25.37671814, 26.18025635, 26.98379456, 27.78733276, 28.59087097,
#         29.39440918]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **Uji Normalitas RH**

# %%
import pandas as pd
df = pd.read_csv(r'/Users/roniabuhanif/Downloads/BMKG/data_skripsi/iklim/kelembaban/nc_to_csv/rh_satuan.csv')

# %%
from scipy.stats import kstest

x = kstest(df['RH'], "norm") 
x
# Out:
# KstestResult(statistic=1.0, pvalue=0.0, statistic_location=60.609893798829546, statistic_sign=-1)

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.hist(df['t2m'])
# Out:
# (array([   78.,   377.,  1365.,  4068.,  5803.,  6997.,  7831., 18233.,
#          8863.,   385.]),
#  array([21.3590271 , 22.16256531, 22.96610352, 23.76964172, 24.57317993,
#         25.37671814, 26.18025635, 26.98379456, 27.78733276, 28.59087097,
#         29.39440918]),
#  <BarContainer object of 10 artists>)
