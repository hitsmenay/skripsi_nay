# %%
import geopandas as gpd
import pandas as pd

# %%
# Total Precipitation preparation
# Load CSV
df_csv = pd.read_csv('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/kualitas_udara/pm10/pm10_satuan.csv')
tp_mean = df_csv.groupby(['longitude', 'latitude'], as_index=False)['pm10'].mean()

# %%
# Load shapefile into a GeoDataFrame
gdf_shapefile = gpd.read_file(r"/Users/roniabuhanif/Downloads/BMKG/data_skripsi/petadki_kecamatan_2/DKI JAKARTA.shp")

# %%
# Convert DataFrame to GeoDataFrame
geometry = gpd.points_from_xy(tp_mean['longitude'], tp_mean['latitude'])
gdf_csv = gpd.GeoDataFrame(tp_mean, geometry=geometry, crs=4326)

# %%
gdf_csv.plot()
gdf_shapefile.plot()
# Out:
# <Axes: >

# %%
# spatial join
result = gpd.sjoin(gdf_csv, gdf_shapefile, how='inner', predicate='intersects')
result_pop = result[['longitude', 'latitude', 'pm10', 'KECAMATAN', 'geometry']]

# %%
result_pop.plot()
result_pop.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 24 entries, 437 to 588
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   longitude  24 non-null     float64
#  1   latitude   24 non-null     float64
#  2   pm10       24 non-null     float64
#  3   KECAMATAN  24 non-null     object
#  4   geometry   24 non-null     geometry
# dtypes: float64(3), geometry(1), object(1)
# memory usage: 1.1+ KB

# %%
dissolved_result = result_pop.dissolve(by='KECAMATAN', aggfunc='mean')
dissolved_result.head(40
                      )
# Out:
#                                                          geometry  longitude  \
# KECAMATAN
# CAKUNG                                 POINT (106.95000 -6.20000)    106.950
# CENGKARENG                             POINT (106.75000 -6.15000)    106.750
# CILANDAK                               POINT (106.80000 -6.30000)    106.800
# CILINCING       MULTIPOINT ((106.95000 -6.15000), (106.95000 -...    106.950
# CIPAYUNG        MULTIPOINT ((106.90000 -6.35000), (106.90000 -...    106.900
# JAGAKARSA       MULTIPOINT ((106.80000 -6.35000), (106.85000 -...    106.825
# KALIDERES       MULTIPOINT ((106.70000 -6.15000), (106.70000 -...    106.700
# KEBAYORAN BARU                         POINT (106.80000 -6.25000)    106.800
# KELAPA GADING                          POINT (106.90000 -6.15000)    106.900
# KEMBANGAN                              POINT (106.75000 -6.20000)    106.750
# KOJA                                   POINT (106.90000 -6.10000)    106.900
# ...

# %%
polygon_result = gpd.sjoin(gdf_shapefile, dissolved_result, how='inner', predicate='intersects')

# %%
polygon_result.plot(column="pm10", legend=True, legend_kwds={"label": "Particulate Matter 10 (PM10)"})
# Out:
# <Axes: >

# %%
polygon_result.to_file('polygon_pm10_result_kecamatan.shp')
# Out:
# /var/folders/81/vqbnjx_x20zdr2m7bscdvp5r0000gn/T/ipykernel_5929/259253194.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   polygon_result.to_file('polygon_pm10_result_kecamatan.shp')
